# %% [markdown]
# # Downsample ch1..ch16 from 125 Hz to 25 Hz
#
# This notebook looks for `*_labeled.csv` files, downsamples `ch1..ch16` by 5x using an anti alias polyphase filter, aligns all other columns to the new length, sets `Sampling Rate` to 25, resets `Sample Index`, and writes `<name>_ds25.csv`.

# %%
# Parameters
INPUT_DIR = "/home/jupyter-yin10/EEG_HAR/PLHI-HAR_EEG-2025_new"
UP = 1
DOWN = 5  # 125 to 25
TARGET_FS = 25
EEG_COLS = [f"ch{i}" for i in range(1, 17)]  # ch1..ch16

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from scipy.signal import resample_poly

inp = Path(INPUT_DIR)
files = sorted([p for p in inp.iterdir() if p.is_file() and p.suffix.lower() == ".csv" and p.name.endswith("_labeled.csv")])
print(f"Found {len(files)} labeled CSV files in {inp}")

def compute_alignment_indices(n_in: int, n_out: int):
    idx = np.round(np.linspace(0, n_in - 1, n_out)).astype(int)
    idx[idx < 0] = 0
    if n_in > 0:
        idx[idx > n_in - 1] = n_in - 1
    return idx

def resample_series(x, up=1, down=5):
    x = np.asarray(x, dtype=np.float64).ravel()
    return resample_poly(x, up=up, down=down)

results = []
for i, f in enumerate(files, start=1):
    try:
        df = pd.read_csv(f)

        # Check columns exist
        missing = [c for c in EEG_COLS if c not in df.columns]
        if missing:
            print(f"[{i:02d}] SKIP {f.name}: missing EEG columns {missing}")
            results.append((f.name, 'skipped_missing_cols'))
            continue

        n_in = len(df)
        if n_in == 0:
            print(f"[{i:02d}] SKIP {f.name}: empty file")
            results.append((f.name, 'skipped_empty'))
            continue

        # Resample target EEG channels
        resampled = {}
        for ch in EEG_COLS:
            resampled[ch] = resample_series(df[ch].values, up=UP, down=DOWN)

        # Confirm common length
        lengths = {k: len(v) for k, v in resampled.items()}
        unique_lengths = set(lengths.values())
        if len(unique_lengths) != 1:
            print(f"[{i:02d}] SKIP {f.name}: inconsistent resampled lengths {lengths}")
            results.append((f.name, 'skipped_inconsistent_lengths'))
            continue
        n_out = unique_lengths.pop()

        # Align non EEG columns by indexing
        idx = compute_alignment_indices(n_in, n_out)
        out_df = df.iloc[idx].copy()

        # Overwrite EEG columns with resampled data
        for ch, y in resampled.items():
            out_df[ch] = y.astype(float)

        # Reset Sample Index if present
        if 'Sample Index' in out_df.columns:
            out_df['Sample Index'] = np.arange(n_out)

        out_path = f.with_name(f.stem.replace('_labeled', '') + '_ds25.csv')
        out_df.to_csv(out_path, index=False)
        print(f"[{i:02d}] OK {f.name}: rows_in={n_in} rows_out={n_out} -> {out_path.name}")
        results.append((f.name, 'ok'))
    except Exception as e:
        print(f"[{i:02d}] ERROR {f.name}: {e}")
        results.append((f.name, f'error: {e}'))

pd.DataFrame(results, columns=['file','status'])
# Out:
# Found 54 labeled CSV files in /home/jupyter-yin10/EEG_HAR/PLHI-HAR_EEG-2025_new
# [01] OK OpenBCISession_s1-chair squats_stacked_labeled.csv: rows_in=57013 rows_out=11403 -> OpenBCISession_s1-chair squats_stacked_ds25.csv
# [02] OK OpenBCISession_s1-light stationary cycling_stacked_labeled.csv: rows_in=57177 rows_out=11436 -> OpenBCISession_s1-light stationary cycling_stacked_ds25.csv
# [03] OK OpenBCISession_s1-marching in place_stacked_labeled.csv: rows_in=51235 rows_out=10247 -> OpenBCISession_s1-marching in place_stacked_ds25.csv
# [04] OK OpenBCISession_s1-seated boxing hooks_stacked_labeled.csv: rows_in=58126 rows_out=11626 -> OpenBCISession_s1-seated boxing hooks_stacked_ds25.csv
# [05] OK OpenBCISession_s1-seated leg extensions_stacked_labeled.csv: rows_in=77573 rows_out=15515 -> OpenBCISession_s1-seated leg extensions_stacked_ds25.csv
# [06] OK OpenBCISession_s1-seated medicine ball twists_stacked_labeled.csv: rows_in=104155 rows_out=20831 -> OpenBCISession_s1-seated medicine ball twists_stacked_ds25.csv
# [07] OK OpenBCISession_s1-seated side bends_stacked_labeled.csv: rows_in=105358 rows_out=21072 -> OpenBCISession_s1-seated side bends_stacked_ds25.csv
# [08] OK OpenBCISession_s1-side-stepping_stacked_labeled.csv: rows_in=55596 rows_out=11120 -> OpenBCISession_s1-side-stepping_stacked_ds25.csv
# [09] OK OpenBCISession_s1-standing heel to toe walk_stacked_labeled.csv: rows_in=98373 rows_out=19675 -> OpenBCISession_s1-standing heel to toe walk_stacked_ds25.csv
# [10] OK OpenBCISession_s1-wall push-ups_stacked_labeled.csv: rows_in=73376 rows_out=14676 -> OpenBCISession_s1-wall push-ups_stacked_ds25.csv
# [11] OK OpenBCISession_s2-chair squats_stacked_labeled.csv: rows_in=58610 rows_out=11722 -> OpenBCISession_s2-chair squats_stacked_ds25.csv
# [12] OK OpenBCISession_s2-light stationary cycling_stacked_labeled.csv: rows_in=39087 rows_out=7818 -> OpenBCISession_s2-light stationary cycling_stacked_ds25.csv
# [13] OK OpenBCISession_s2-marching in place_stacked_labeled.csv: rows_in=56735 rows_out=11347 -> OpenBCISession_s2-marching in place_stacked_ds25.csv
# [14] OK OpenBCISession_s2-seated boxing hooks_stacked_labeled.csv: rows_in=58197 rows_out=11640 -> OpenBCISession_s2-seated boxing hooks_stacked_ds25.csv
# [15] OK OpenBCISession_s2-seated leg extensions_stacked_labeled.csv: rows_in=57474 rows_out=11495 -> OpenBCISession_s2-seated leg extensions_stacked_ds25.csv
# [16] OK OpenBCISession_s2-seated medicine ball twists_stacked_labeled.csv: rows_in=38833 rows_out=7767 -> OpenBCISession_s2-seated medicine ball twists_stacked_ds25.csv
# [17] OK OpenBCISession_s2-seated side bends_stacked_labeled.csv: rows_in=57756 rows_out=11552 -> OpenBCISession_s2-seated side bends_stacked_ds25.csv
# [18] OK OpenBCISession_s2-side-stepping_stacked_labeled.csv: rows_in=59341 rows_out=11869 -> OpenBCISession_s2-side-stepping_stacked_ds25.csv
# [19] OK OpenBCISession_s2-standing heel to toe walk_stacked_labeled.csv: rows_in=56499 rows_out=11300 -> OpenBCISession_s2-standing heel to toe walk_stacked_ds25.csv
# [20] OK OpenBCISession_s2-wall push-ups_stacked_labeled.csv: rows_in=73357 rows_out=14672 -> OpenBCISession_s2-wall push-ups_stacked_ds25.csv
# [21] OK OpenBCISession_s3-chair squats_stacked_labeled.csv: rows_in=56507 rows_out=11302 -> OpenBCISession_s3-chair squats_stacked_ds25.csv
# [22] OK OpenBCISession_s3-light stationary cycling_stacked_labeled.csv: rows_in=67973 rows_out=13595 -> OpenBCISession_s3-light stationary cycling_stacked_ds25.csv
# [23] OK OpenBCISession_s3-marching in place_stacked_labeled.csv: rows_in=55746 rows_out=11150 -> OpenBCISession_s3-marching in place_stacked_ds25.csv
# [24] OK OpenBCISession_s3-seated boxing hooks_stacked_labeled.csv: rows_in=56727 rows_out=11346 -> OpenBCISession_s3-seated boxing hooks_stacked_ds25.csv
# [25] OK OpenBCISession_s3-seated leg extensions_stacked_labeled.csv: rows_in=57751 rows_out=11551 -> OpenBCISession_s3-seated leg extensions_stacked_ds25.csv
# [26] OK OpenBCISession_s3-seated medicine ball twists_stacked_labeled.csv: rows_in=58848 rows_out=11770 -> OpenBCISession_s3-seated medicine ball twists_stacked_ds25.csv
# [27] OK OpenBCISession_s3-seated side bends_stacked_labeled.csv: rows_in=56905 rows_out=11381 -> OpenBCISession_s3-seated side bends_stacked_ds25.csv
# [28] OK OpenBCISession_s3-side-stepping_stacked_labeled.csv: rows_in=58061 rows_out=11613 -> OpenBCISession_s3-side-stepping_stacked_ds25.csv
# [29] OK OpenBCISession_s3-standing heel to toe walk_stacked_labeled.csv: rows_in=56257 rows_out=11252 -> OpenBCISession_s3-standing heel to toe walk_stacked_ds25.csv
# [30] OK OpenBCISession_s3-wall push-ups_stacked_labeled.csv: rows_in=37939 rows_out=7588 -> OpenBCISession_s3-wall push-ups_stacked_ds25.csv
# [31] OK OpenBCISession_s4-chair squats_stacked_labeled.csv: rows_in=54689 rows_out=10938 -> OpenBCISession_s4-chair squats_stacked_ds25.csv
# [32] OK OpenBCISession_s4-light stationary cycling_stacked_labeled.csv: rows_in=57393 rows_out=11479 -> OpenBCISession_s4-light stationary cycling_stacked_ds25.csv
# [33] OK OpenBCISession_s4-marching in place_stacked_labeled.csv: rows_in=38651 rows_out=7731 -> OpenBCISession_s4-marching in place_stacked_ds25.csv
# [34] OK OpenBCISession_s4-seated boxing hooks_stacked_labeled.csv: rows_in=63259 rows_out=12652 -> OpenBCISession_s4-seated boxing hooks_stacked_ds25.csv
# [35] OK OpenBCISession_s4-seated leg extensions_stacked_labeled.csv: rows_in=57703 rows_out=11541 -> OpenBCISession_s4-seated leg extensions_stacked_ds25.csv
# [36] OK OpenBCISession_s4-seated medicine ball twists_stacked_labeled.csv: rows_in=58442 rows_out=11689 -> OpenBCISession_s4-seated medicine ball twists_stacked_ds25.csv
# [37] OK OpenBCISession_s4-seated side bends_stacked_labeled.csv: rows_in=58661 rows_out=11733 -> OpenBCISession_s4-seated side bends_stacked_ds25.csv
# [38] OK OpenBCISession_s4-side-stepping_stacked_labeled.csv: rows_in=38580 rows_out=7716 -> OpenBCISession_s4-side-stepping_stacked_ds25.csv
# [39] OK OpenBCISession_s4-standing heel to toe walk_stacked_labeled.csv: rows_in=58313 rows_out=11663 -> OpenBCISession_s4-standing heel to toe walk_stacked_ds25.csv
# [40] OK OpenBCISession_s4-wall push-ups_stacked_labeled.csv: rows_in=58128 rows_out=11626 -> OpenBCISession_s4-wall push-ups_stacked_ds25.csv
# [41] OK OpenBCISession_s5-marching in place_stacked_labeled.csv: rows_in=58514 rows_out=11703 -> OpenBCISession_s5-marching in place_stacked_ds25.csv
# [42] OK OpenBCISession_s5-seated boxing hooks_stacked_labeled.csv: rows_in=15165 rows_out=3033 -> OpenBCISession_s5-seated boxing hooks_stacked_ds25.csv
# [43] OK OpenBCISession_s5-standing heel to toe walk_stacked_labeled.csv: rows_in=15281 rows_out=3057 -> OpenBCISession_s5-standing heel to toe walk_stacked_ds25.csv
# [44] OK OpenBCISession_s5-wall push-ups_stacked_labeled.csv: rows_in=57389 rows_out=11478 -> OpenBCISession_s5-wall push-ups_stacked_ds25.csv
# [45] OK OpenBCISession_s6- standing heel to toe walk_stacked_labeled.csv: rows_in=57534 rows_out=11507 -> OpenBCISession_s6- standing heel to toe walk_stacked_ds25.csv
# [46] OK OpenBCISession_s6-chair squats_stacked_labeled.csv: rows_in=58742 rows_out=11749 -> OpenBCISession_s6-chair squats_stacked_ds25.csv
# [47] OK OpenBCISession_s6-light stationary cycling_stacked_labeled.csv: rows_in=15078 rows_out=3016 -> OpenBCISession_s6-light stationary cycling_stacked_ds25.csv
# [48] OK OpenBCISession_s6-marchinginplace_stacked_labeled.csv: rows_in=57388 rows_out=11478 -> OpenBCISession_s6-marchinginplace_stacked_ds25.csv
# [49] OK OpenBCISession_s6-seated boxing hooks_stacked_labeled.csv: rows_in=58312 rows_out=11663 -> OpenBCISession_s6-seated boxing hooks_stacked_ds25.csv
# [50] OK OpenBCISession_s6-seated leg extensions_stacked_labeled.csv: rows_in=73235 rows_out=14647 -> OpenBCISession_s6-seated leg extensions_stacked_ds25.csv
# [51] OK OpenBCISession_s6-seated medicine ball twists_stacked_labeled.csv: rows_in=57794 rows_out=11559 -> OpenBCISession_s6-seated medicine ball twists_stacked_ds25.csv
# [52] OK OpenBCISession_s6-seated side bends_stacked_labeled.csv: rows_in=57356 rows_out=11472 -> OpenBCISession_s6-seated side bends_stacked_ds25.csv
# [53] OK OpenBCISession_s6-side-stepping_stacked_labeled.csv: rows_in=38086 rows_out=7618 -> OpenBCISession_s6-side-stepping_stacked_ds25.csv
# [54] OK OpenBCISession_s6-wallpushups_stacked_labeled.csv: rows_in=59320 rows_out=11864 -> OpenBCISession_s6-wallpushups_stacked_ds25.csv
#                                                  file status
# 0   OpenBCISession_s1-chair squats_stacked_labeled...     ok
# 1   OpenBCISession_s1-light stationary cycling_sta...     ok
# 2   OpenBCISession_s1-marching in place_stacked_la...     ok
# 3   OpenBCISession_s1-seated boxing hooks_stacked_...     ok
# 4   OpenBCISession_s1-seated leg extensions_stacke...     ok
# 5   OpenBCISession_s1-seated medicine ball twists_...     ok
# 6   OpenBCISession_s1-seated side bends_stacked_la...     ok
# 7   OpenBCISession_s1-side-stepping_stacked_labele...     ok
# 8   OpenBCISession_s1-standing heel to toe walk_st...     ok
# 9   OpenBCISession_s1-wall push-ups_stacked_labele...     ok
# 10  OpenBCISession_s2-chair squats_stacked_labeled...     ok
# 11  OpenBCISession_s2-light stationary cycling_sta...     ok
# 12  OpenBCISession_s2-marching in place_stacked_la...     ok
# 13  OpenBCISession_s2-seated boxing hooks_stacked_...     ok
# 14  OpenBCISession_s2-seated leg extensions_stacke...     ok
# 15  OpenBCISession_s2-seated medicine ball twists_...     ok
# 16  OpenBCISession_s2-seated side bends_stacked_la...     ok
# 17  OpenBCISession_s2-side-stepping_stacked_labele...     ok
# 18  OpenBCISession_s2-standing heel to toe walk_st...     ok
# 19  OpenBCISession_s2-wall push-ups_stacked_labele...     ok
# 20  OpenBCISession_s3-chair squats_stacked_labeled...     ok
# 21  OpenBCISession_s3-light stationary cycling_sta...     ok
# 22  OpenBCISession_s3-marching in place_stacked_la...     ok
# 23  OpenBCISession_s3-seated boxing hooks_stacked_...     ok
# 24  OpenBCISession_s3-seated leg extensions_stacke...     ok
# 25  OpenBCISession_s3-seated medicine ball twists_...     ok
# 26  OpenBCISession_s3-seated side bends_stacked_la...     ok
# 27  OpenBCISession_s3-side-stepping_stacked_labele...     ok
# 28  OpenBCISession_s3-standing heel to toe walk_st...     ok
# 29  OpenBCISession_s3-wall push-ups_stacked_labele...     ok
# 30  OpenBCISession_s4-chair squats_stacked_labeled...     ok
# 31  OpenBCISession_s4-light stationary cycling_sta...     ok
# 32  OpenBCISession_s4-marching in place_stacked_la...     ok
# 33  OpenBCISession_s4-seated boxing hooks_stacked_...     ok
# 34  OpenBCISession_s4-seated leg extensions_stacke...     ok
# 35  OpenBCISession_s4-seated medicine ball twists_...     ok
# 36  OpenBCISession_s4-seated side bends_stacked_la...     ok
# 37  OpenBCISession_s4-side-stepping_stacked_labele...     ok
# 38  OpenBCISession_s4-standing heel to toe walk_st...     ok
# 39  OpenBCISession_s4-wall push-ups_stacked_labele...     ok
# 40  OpenBCISession_s5-marching in place_stacked_la...     ok
# 41  OpenBCISession_s5-seated boxing hooks_stacked_...     ok
# 42  OpenBCISession_s5-standing heel to toe walk_st...     ok
# 43  OpenBCISession_s5-wall push-ups_stacked_labele...     ok
# 44  OpenBCISession_s6- standing heel to toe walk_s...     ok
# 45  OpenBCISession_s6-chair squats_stacked_labeled...     ok
# 46  OpenBCISession_s6-light stationary cycling_sta...     ok
# 47  OpenBCISession_s6-marchinginplace_stacked_labe...     ok
# 48  OpenBCISession_s6-seated boxing hooks_stacked_...     ok
# 49  OpenBCISession_s6-seated leg extensions_stacke...     ok
# 50  OpenBCISession_s6-seated medicine ball twists_...     ok
# 51  OpenBCISession_s6-seated side bends_stacked_la...     ok
# 52  OpenBCISession_s6-side-stepping_stacked_labele...     ok
# 53  OpenBCISession_s6-wallpushups_stacked_labeled.csv     ok
